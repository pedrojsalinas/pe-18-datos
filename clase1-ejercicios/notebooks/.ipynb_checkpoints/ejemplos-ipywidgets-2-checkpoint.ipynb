# %%
import ipywidgets as widgets
import pandas as pd

# %%
from IPython.display import display

w = widgets.Dropdown(
    options=['1', '2', '3'],
    value='2',
    description='Number:',
    disabled=False,
)
display(w)
# Out:
# Dropdown(description=u'Number:', index=1, options=('1', '2', '3'), value='2')

# %%
for i in range(0, int(w.value)):
    print i
# Out:
# 0
# 1

# %%
data = pd.read_csv("data/data-educacion-ecuador.csv")
print data.keys()
#data.Provincia
# Out:
# Index([u'Provincia', u'Canton', u'Parroquia', u'Femenino', u'Masculino',
#        u'Textbox17', u'Textbox6', u'Textbox7', u'Textbox18'],
#       dtype='object')

# %%
w = widgets.Dropdown(
    options=['ZAMORA CHINCHIPE', 'AZUAY', 'LOJA'],
    value='LOJA',
    description='Provincia:',
    disabled=False,
)
display(w)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-9-517dff8e6214> in <module>()
#       3     value='LOJA',
#       4     description='Provincia:',
# ----> 5     disabled=False,
#       6 )
#       7 display(w)
#
# /root/Documents/UTPL/PE2/ejercicios-datos/pe-18-datos/entorno/local/lib/python2.7/site-packages/ipywidgets/widgets/widget_selection.pyc in __init__(self, *args, **kwargs)
#     177         # so we don't have errors the first time validators run
#     178         self._initializing_traits_ = True
# --> 179         options = _make_options(kwargs.get('options', ()))
#     180         self._options_full = options
#     181         self.set_trait('_options_labels', tuple(i[0] for i in options))
#
# /root/Documents/UTPL/PE2/ejercicios-datos/pe-18-datos/entorno/local/lib/python2.7/site-packages/ipywidgets/widgets/widget_selection.pyc in _make_options(x)
#     130
#     131     # Otherwise, assume x is an iterable of values
# --> 132     return tuple((unicode_type(i), i) for i in xlist)
#     133
#     134 def findvalue(array, value, compare = lambda x, y: x == y):
#
# /root/Documents/UTPL/PE2/ejercicios-datos/pe-18-datos/entorno/local/lib/python2.7/site-packages/ipywidgets/widgets/widget_selection.pyc in <genexpr>((i,))
#     130
#     131     # Otherwise, assume x is an iterable of values
# --> 132     return tuple((unicode_type(i), i) for i in xlist)
#     133
#     134 def findvalue(array, value, compare = lambda x, y: x == y):
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc3 in position 2: ordinal not in range(128)

# %%
data[data['Provincia']==w.value]
# Out:
#    Provincia                 Canton                              Parroquia  \
# 0      AZUAY  CAMILO PONCE ENRIQUEZ                  CAMILO PONCE ENRIQUEZ
# 1      AZUAY  CAMILO PONCE ENRIQUEZ                   EL CARMEN DEL PIJILI
# 2      AZUAY              CHORDELEG                              CHORDELEG
# 3      AZUAY              CHORDELEG                               LA UNION
# 4      AZUAY              CHORDELEG                  LUIS GALARZA ORELLANA
# 5      AZUAY              CHORDELEG                              PRINCIPAL
# 6      AZUAY              CHORDELEG                   SAN MARTIN DE PUZHIO
# 7      AZUAY                 CUENCA                                  BAÑOS
# 8      AZUAY                 CUENCA                             BELLAVISTA
# 9      AZUAY                 CUENCA                            CAÑARIBAMBA
# 10     AZUAY                 CUENCA                                CHAUCHA
# 11     AZUAY                 CUENCA                         CHECA (JIDCAY)
# 12     AZUAY                 CUENCA                             CHIQUINTAD
# 13     AZUAY                 CUENCA                                  CUMBE
# 14     AZUAY                 CUENCA                               EL BATAN
# 15     AZUAY                 CUENCA                            EL SAGRARIO
# 16     AZUAY                 CUENCA                              EL VECINO
# 17     AZUAY                 CUENCA                    GIL RAMIREZ DAVALOS
# 18     AZUAY                 CUENCA                         HERMANO MIGUEL
# 19     AZUAY                 CUENCA                            HUAYNACAPAC
# 20     AZUAY                 CUENCA                                 LLACAO
# 21     AZUAY                 CUENCA                             MACHANGARA
# 22     AZUAY                 CUENCA                              MOLLETURO
# 23     AZUAY                 CUENCA                                  MONAY
# 24     AZUAY                 CUENCA                                  NULTI
# 25     AZUAY                 CUENCA  OCTAVIO CORDERO PALACIOS (SANTA ROSA)
# 26     AZUAY                 CUENCA                                 PACCHA
# 27     AZUAY                 CUENCA                                QUINGEO
# 28     AZUAY                 CUENCA                               RICAURTE
# 29     AZUAY                 CUENCA                               SAN BLAS
# ..       ...                    ...                                    ...
# 59     AZUAY                  NABON                     LAS NIEVES (CHAYA)
# 60     AZUAY                  NABON                                  NABON
# 61     AZUAY                    OÑA                      SAN FELIPE DE OÑA
# 62     AZUAY                    OÑA                                SUSUDEL
# 63     AZUAY                  PAUTE          BULAN (JOSE VICTOR IZQUIERDO)
# 64     AZUAY                  PAUTE              CHICAN (GUILLERMO ORTEGA)
# 65     AZUAY                  PAUTE                                DUG DUG
# 66     AZUAY                  PAUTE                                EL CABO
# 67     AZUAY                  PAUTE                              GUARAINAG
# 68     AZUAY                  PAUTE                                  PAUTE
# 69     AZUAY                  PAUTE    SAN CRISTOBAL (CARLOS ORDOÑEZ LAZO)
# 70     AZUAY                  PAUTE                              TOMEBAMBA
# 71     AZUAY                 PUCARA                                 PUCARA
# 72     AZUAY                 PUCARA                   SAN RAFAEL DE SHARUG
# 73     AZUAY           SAN FERNANDO                               CHUMBLIN
# 74     AZUAY           SAN FERNANDO                           SAN FERNANDO
# 75     AZUAY           SANTA ISABEL              ABDON CALDERON (LA UNION)
# 76     AZUAY           SANTA ISABEL                    EL CARMEN DE PIJILI
# 77     AZUAY           SANTA ISABEL             SANTA ISABEL (CHAGUARURCO)
# 78     AZUAY           SANTA ISABEL                      ZHAGLLI (SHAGLLI)
# 79     AZUAY         SEVILLA DE ORO                                AMALUZA
# 80     AZUAY         SEVILLA DE ORO                                 PALMAS
# 81     AZUAY         SEVILLA DE ORO                         SEVILLA DE ORO
# 82     AZUAY                 SIGSIG                       CUCHIL (CUTCHIL)
# 83     AZUAY                 SIGSIG                                   GÜEL
# 84     AZUAY                 SIGSIG                            JIMA (GIMA)
# 85     AZUAY                 SIGSIG                                   LUDO
# 86     AZUAY                 SIGSIG                          SAN BARTOLOME
# 87     AZUAY                 SIGSIG                    SAN JOSE DE RARANGA
# 88     AZUAY                 SIGSIG                                 SIGSIG
#
#    Femenino Masculino Textbox17   Textbox6   Textbox7  Textbox18
# 0     2,294     2,096     4,390  1,945,017  1,767,520  3,712,537
# 1       215       173       388  1,945,017  1,767,520  3,712,537
# 2     1,183     1,109     2,292  1,945,017  1,767,520  3,712,537
# 3       134       128       262  1,945,017  1,767,520  3,712,537
# 4       156       155       311  1,945,017  1,767,520  3,712,537
# 5       212       225       437  1,945,017  1,767,520  3,712,537
# 6       136       128       264  1,945,017  1,767,520  3,712,537
# 7     2,915     4,796     7,711  1,945,017  1,767,520  3,712,537
