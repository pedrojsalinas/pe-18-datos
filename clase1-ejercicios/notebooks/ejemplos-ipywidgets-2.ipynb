# %%
import ipywidgets as widgets
import pandas as pd

# %%
from IPython.display import display

w = widgets.Dropdown(
    options=['1', '2', '3'],
    value='2',
    description='Number:',
    disabled=False,
)
display(w)
# Out:
# Dropdown(description='Number:', index=1, options=('1', '2', '3'), value='2')

# %%
for i in range(0, int(w.value)):
    print (i)
# Out:
# 0
# 1

# %%
data = pd.read_csv("data/data-educacion-ecuador.csv")
print (data.keys())
#data.Provincia
# Out:
# Index(['Provincia', 'Canton', 'Parroquia', 'Femenino', 'Masculino',
#        'Textbox17', 'Textbox6', 'Textbox7', 'Textbox18'],
#       dtype='object')

# %%
w = widgets.Dropdown(
    options=['ZAMORA CHINCHIPE', 'AZUAY', 'LOJA'],
    value='LOJA',
    description='Provincia:',
    disabled=False,
)
display(w)
# Out:
# Dropdown(description='Provincia:', index=2, options=('ZAMORA CHINCHIPE', 'AZUAY', 'LOJA'), value='LOJA')

# %%
data[data['Provincia']==w.value]
# Out:
#     Provincia        Canton                           Parroquia Femenino  \
# 579      LOJA        CALVAS                          CARIAMANGA    2,451
# 580      LOJA        CALVAS                               CHILE      674
# 581      LOJA        CALVAS                           COLAISACA      328
# 582      LOJA        CALVAS                           EL LUCERO      374
# 583      LOJA        CALVAS                         SAN VICENTE      654
# 584      LOJA        CALVAS                          SANGUILLIN      206
# 585      LOJA        CALVAS                              UTUANA      165
# 586      LOJA      CATAMAYO                            CATAMAYO    3,466
# 587      LOJA      CATAMAYO                            EL TAMBO      493
# 588      LOJA      CATAMAYO                        GUAYQUICHUMA       24
# 589      LOJA      CATAMAYO             SAN PEDRO DE LA BENDITA      231
# 590      LOJA      CATAMAYO                               ZAMBI       79
# 591      LOJA        CELICA                              CELICA      984
# 592      LOJA        CELICA                           CRUZPAMBA      171
# 593      LOJA        CELICA           POZUL (SAN JUAN DE POZUL)      446
# 594      LOJA        CELICA                           SABANILLA      268
# 595      LOJA        CELICA  TNTE. MAXIMILIANO RODRIGUEZ LOAIZA       49
# 596      LOJA  CHAGUARPAMBA                           AMARILLOS      101
# 597      LOJA  CHAGUARPAMBA                          BUENAVISTA      168
# 598      LOJA  CHAGUARPAMBA                        CHAGUARPAMBA      517
# 599      LOJA  CHAGUARPAMBA                          EL ROSARIO       46
# 600      LOJA  CHAGUARPAMBA                        SANTA RUFINA      154
# 601      LOJA     ESPINDOLA                         27 DE ABRIL      233
# 602      LOJA     ESPINDOLA                             AMALUZA      796
# 603      LOJA     ESPINDOLA                          BELLAVISTA      214
# 604      LOJA     ESPINDOLA                             EL AIRO      168
# 605      LOJA     ESPINDOLA                          EL INGENIO      326
# 606      LOJA     ESPINDOLA                             JIMBURA      377
# 607      LOJA     ESPINDOLA                      SANTA TERESITA      279
# 608      LOJA     GONZANAMA           CHANGAIMINA (LA LIBERTAD)      366
# ..        ...           ...                                 ...      ...
# 648      LOJA        PINDAL                           CHAQUINAL      126
# 649      LOJA        PINDAL                              PINDAL      847
# 650      LOJA       PUYANGO                              ALAMOR    1,306
# 651      LOJA       PUYANGO                               CIANO      198
# 652      LOJA       PUYANGO                           EL ARENAL      139
# 653      LOJA       PUYANGO          EL LIMO (MARIANA DE JESUS)      254
# 654      LOJA       PUYANGO                          MERCADILLO      130
# 655      LOJA       PUYANGO                           VICENTINO      146
# 656      LOJA      QUILANGA                         FUNDOCHAMBA       34
# 657      LOJA      QUILANGA                            QUILANGA      361
# 658      LOJA      QUILANGA           SAN ANTONIO DE LAS ARADAS      152
# 659      LOJA      SARAGURO                 EL PARAISO DE CELEN      363
# 660      LOJA      SARAGURO                           EL TABLON       64
# 661      LOJA      SARAGURO                            LLUZHAPA      215
# 662      LOJA      SARAGURO                                MANU      389
# 663      LOJA      SARAGURO        SAN ANTONIO DE QUMBE (CUMBE)      132
# 664      LOJA      SARAGURO                  SAN PABLO DE TENTA      526
# 665      LOJA      SARAGURO              SAN SEBASTIAN DE YULUC      130
# 666      LOJA      SARAGURO                            SARAGURO    1,871
# 667      LOJA      SARAGURO                        SELVA ALEGRE      263
# 668      LOJA      SARAGURO                          SUMAYPAMBA      206
# 669      LOJA      SARAGURO               URDANETA (PAQUISHAPA)      508
# 670      LOJA     SOZORANGA                        NUEVA FATIMA      137
# 671      LOJA     SOZORANGA                           SOZORANGA      290
# 672      LOJA     SOZORANGA                           TACAMOROS      315
# 673      LOJA     ZAPOTILLO        CAZADEROS (CAB.EN MANGAURCO)      167
# 674      LOJA     ZAPOTILLO                           GARZAREAL      156
# 675      LOJA     ZAPOTILLO                             LIMONES      154
# 676      LOJA     ZAPOTILLO                          PALETILLAS      310
# 677      LOJA     ZAPOTILLO                           ZAPOTILLO      699
#
#     Masculino Textbox17   Textbox6   Textbox7  Textbox18
# 579     2,024     4,475  1,945,017  1,767,520  3,712,537
# 580       443     1,117  1,945,017  1,767,520  3,712,537
# 581       319       647  1,945,017  1,767,520  3,712,537
# 582       322       696  1,945,017  1,767,520  3,712,537
# 583       671     1,325  1,945,017  1,767,520  3,712,537
# 584       196       402  1,945,017  1,767,520  3,712,537
# 585       179       344  1,945,017  1,767,520  3,712,537
# 586     2,916     6,382  1,945,017  1,767,520  3,712,537
# 587       531     1,024  1,945,017  1,767,520  3,712,537
# 588        27        51  1,945,017  1,767,520  3,712,537
# 589       332       563  1,945,017  1,767,520  3,712,537
