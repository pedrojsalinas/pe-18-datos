# %%
import pandas as pd
import sys
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from pandas.tools.plotting import radviz
import scipy as sp                  # Importamos scipy como el alias sp


# %matplotlib inline

# %%
ls
# Out:
# datos-tabula/           Ejemplo02-matematicas.ipynb
# Ejemplo01-Scipy.ipynb*  Ejemplo03-json.ipynb

# %%
# mi_df = pd.read_json('datos-tabula/paises.json', orient='columns')
mi_df = pd.read_json('datos-tabula/paises.json')

# %%
mi_df
# Out:
#     alpha-2 alpha-3  country-code intermediate-region  \
# 0        AF     AFG             4
# 1        AX     ALA           248
# 2        AL     ALB             8
# 3        DZ     DZA            12
# 4        AS     ASM            16
# 5        AD     AND            20
# 6        AO     AGO            24       Middle Africa
# 7        AI     AIA           660           Caribbean
# 8        AQ     ATA            10
# 9        AG     ATG            28           Caribbean
# 10       AR     ARG            32       South America
# 11       AM     ARM            51
# 12       AW     ABW           533           Caribbean
# 13       AU     AUS            36
# 14       AT     AUT            40
# 15       AZ     AZE            31
# 16       BS     BHS            44           Caribbean
# 17       BH     BHR            48
# 18       BD     BGD            50
# 19       BB     BRB            52           Caribbean
# 20       BY     BLR           112
# 21       BE     BEL            56
# ...

# %%
mi_df.to_csv("datos-tabula/paises.csv", encoding='latin-1')

# %%
mi_df2 = pd.read_csv('datos-tabula/paises.csv')
mi_df2
# Out:
#      Unnamed: 0 alpha-2 alpha-3  country-code intermediate-region  \
# 0             0      AF     AFG             4                 NaN
# 1             1      AX     ALA           248                 NaN
# 2             2      AL     ALB             8                 NaN
# 3             3      DZ     DZA            12                 NaN
# 4             4      AS     ASM            16                 NaN
# 5             5      AD     AND            20                 NaN
# 6             6      AO     AGO            24       Middle Africa
# 7             7      AI     AIA           660           Caribbean
# 8             8      AQ     ATA            10                 NaN
# 9             9      AG     ATG            28           Caribbean
# 10           10      AR     ARG            32       South America
# 11           11      AM     ARM            51                 NaN
# 12           12      AW     ABW           533           Caribbean
# ...

# %%
mi_df2.describe()
# Out:
#        Unnamed: 0  country-code  intermediate-region-code  region-code  \
# count  249.000000    249.000000                107.000000   248.000000
# mean   124.000000    433.835341                 31.719626    65.951613
# std     72.024301    252.980446                111.000322    67.347832
# min      0.000000      4.000000                  5.000000     2.000000
# 25%     62.000000    218.000000                 11.000000     9.000000
# 50%    124.000000    434.000000                 14.000000    19.000000
# 75%    186.000000    652.000000                 29.000000   142.000000
# max    248.000000    894.000000                830.000000   150.000000
#
#        sub-region-code
# count       248.000000
# mean        179.866935
# std         138.334170
# min          15.000000
# 25%          53.750000
# 50%         154.000000
# 75%         202.000000
# max         419.000000

# %%
mi_df2.sum()
# Out:
# Unnamed: 0                                                              30876
# alpha-3                     AFGALAALBDZAASMANDAGOAIAATAATGARGARMABWAUSAUTA...
# country-code                                                           108025
# intermediate-region-code                                                 3394
# iso_3166-2                  ISO 3166-2:AFISO 3166-2:AXISO 3166-2:ALISO 316...
# name                        Afghanistan�land IslandsAlbaniaAlgeriaAmerican...
# region-code                                                             16356
# sub-region-code                                                         44607
# dtype: object
