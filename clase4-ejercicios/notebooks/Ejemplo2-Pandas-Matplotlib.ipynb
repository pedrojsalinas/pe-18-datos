# %%
import pandas as pd
import sys
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from pandas.tools.plotting import radviz

# %matplotlib inline

# %%
ls
# Out:
# data/                              Ejemplo-Pandas-05-1.ipynb
# Ejemplo2-Pandas-Matplotlib.ipynb*  Ejemplo-Pandas-05.ipynb
# Ejemplo-Matplotlib.ipynb*          Ejemplo-Pandas-06.ipynb
# Ejemplo-Pandas-01.ipynb            Ejemplo-Pandas-07-1.ipynb
# Ejemplo-Pandas-02.ipynb            Ejemplo-Pandas-07.ipynb
# Ejemplo-Pandas-03.ipynb            Ejemplo-Pandas-08.ipynb
# Ejemplo-Pandas-04-1.ipynb          Ejemplo-Pandas-Matplotlib.ipynb*
# Ejemplo-Pandas-04.ipynb            notebook-py3/

# %%
df = pd.read_csv("data/Matrimonios_2014.csv")

# %%
df.keys()
# Out:
# Index([u'Unnamed: 0', u'ofi_insc', u'prov_insc', u'cant_insc', u'parr_insc',
#        u'anio_insc', u'mes_insc', u'dia_insc', u'fecha_insc', u'hijos_rec',
#        u'mcap_bie', u'nac_hom', u'cod_paish', u'anio_nach', u'mes_nach',
#        u'dia_nach', u'fecha_nach', u'edad_hom', u'nmatanth', u'est_civih',
#        u'p_etnica_hom', u'sabe_leerh', u'niv_insth', u'prov_habh',
#        u'cant_habh', u'parr_habh', u'area_hom', u'nac_muj', u'cod_paism',
#        u'anio_nacm', u'mes_nacm', u'dia_nacm', u'fecha_nacm', u'edad_muj',
#        u'nmatantm', u'est_civim', u'p_etnica_muj', u'sabe_leerm', u'niv_instm',
#        u'prov_habm', u'cant_habm', u'parr_habm', u'area_muj'],
#       dtype='object')

# %%
df[df['prov_insc'].str.strip()=='Loja'].mes_insc.value_counts()[:12].sort_values(inplace=False).plot('barh');

# %%
df[df['prov_insc'].str.strip()=='Guayas'].mes_insc.value_counts(normalize=True)[:15]\
.sort_values(inplace=False).plot('barh');

# %%
df[df['prov_insc'].str.strip()=='Loja'].mes_insc.value_counts(normalize=True)[:15]\
.sort_values(inplace=False).plot('barh');
